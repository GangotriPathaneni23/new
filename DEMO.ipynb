# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>Pathaneni Gangotri

# %% [markdown]
# Data Analyst

# %% [markdown]
# *I am interested in data science because I love to visualize data and make use of data in a proper way*

# %% [markdown]
# ### The following code displays 1 to 5 numbers

# %%
i=1;
while(i<=5):
    print(i);
    i=i+1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# - This is bullet
#     - This is sub bullet
# 1. This number list
# 2. This number list
#     1. This is sub line
#
# [Click here to google](https://www.google.com/)
